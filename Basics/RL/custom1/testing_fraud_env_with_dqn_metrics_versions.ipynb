# %%
import sys
sys.path.append(r"C:\Users\anton\Documents\programming\python\ML\RL\gym-fraud-master_v3")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\anton\\Documents\\programming\\python\\ML\\RL\\gym-fraud-master_v3'

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'dataset',
#  'Deep RL code',
#  'fraud_dqn_xgb_svm_notebook_so_aprende_fraude.ipynb',
#  'fraud_env_with_dqn_metrics.py',
#  'gymfraud_py311_smote_v4.yml',
#  'gym_fraud',
#  'gym_fraud.egg-info',
#  'images',
#  'README.md',
#  'requirements - Copia.txt',
#  'requirements.txt',
#  'results_notebook',
#  'RL_fraud_env_3_teste_v1.ipynb',
#  'running_compleated_RL_fraud_inside_v1.py',
#  'setup.py',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  '__pycache__']

# %%
from fraud_env_with_dqn_metrics import train_dqn_with_metrics
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from fraud_env_with_dqn_metrics import train_dqn_with_metrics
#
# ImportError: cannot import name 'train_dqn_with_metrics' from 'fraud_env_with_dqn_metrics' (C:\Users\anton\Documents\programming\python\ML\RL\gym-fraud-master_v3\fraud_env_with_dqn_metrics.py)

# %%
import fraud_env_with_dqn_metrics
fraud_env_with_dqn_metrics.__file__
# Out:
# 'C:\\Users\\anton\\Documents\\programming\\python\\ML\\RL\\gym-fraud-master_v3\\fraud_env_with_dqn_metrics.py'

# %%
fraud_env_with_dqn_metrics.__file__
# Out:
# 'C:\\Users\\anton\\Documents\\programming\\python\\ML\\RL\\gym-fraud-master_v3\\fraud_env_with_dqn_metrics.py'

# %%
# %pwd
# Out:
# 'C:\\Users\\anton\\Documents\\programming\\python\\ML\\RL\\gym-fraud-master_v3'

# %%
# %ls
# Out:
#  O volume na unidade C nÆo tem nome.
#  O N£mero de S‚rie do Volume ‚ F8B2-7C53
#
#  Pasta de C:\Users\anton\Documents\programming\python\ML\RL\gym-fraud-master_v3
#
# 17/11/2025  18:10    <DIR>          .
# 17/11/2025  11:17    <DIR>          ..
# 17/11/2025  16:43    <DIR>          .ipynb_checkpoints
# 17/11/2025  18:08    <DIR>          __pycache__
# 17/11/2025  14:13    <DIR>          dataset
# 17/11/2025  11:17    <DIR>          Deep RL code
# 17/11/2025  16:53            92.262 fraud_dqn_xgb_svm_notebook_so_aprende_fraude.ipynb
# 17/11/2025  18:11            16.370 fraud_env_with_dqn_metrics.py
# 17/11/2025  13:47    <DIR>          gym_fraud
# 17/11/2025  15:15    <DIR>          gym_fraud.egg-info
# 17/11/2025  16:48             4.382 gymfraud_py311_smote_v4.yml
# 17/11/2025  11:17    <DIR>          images
# 17/11/2025  11:17             3.479 README.md
# 17/11/2025  11:42               291 requirements - Copia.txt
# 17/11/2025  15:04               305 requirements.txt
# ...

# %%
import importlib
import fraud_env_with_dqn_metrics
importlib.reload(fraud_env_with_dqn_metrics)
# Out:
# <module 'fraud_env_with_dqn_metrics' from 'C:\\Users\\anton\\Documents\\programming\\python\\ML\\RL\\gym-fraud-master_v3\\fraud_env_with_dqn_metrics.py'>

# %%
from fraud_env_with_dqn_metrics import train_dqn_with_metrics

# %%
policy, target, memory = train_dqn_with_metrics(
    csv_path="dataset/creditcard.csv",
    n_episodes=40,        # coloque mais tarde para 200 ou 500
    max_steps_per_episode=1000,
    batch_size=128,
    moving_avg_window=10
)
# Out:
# Episode    1 | steps= 12 | reward_sum=3.00 | recall=0.0000 | f1=0.0000 | precision=0.0000
#   >>> Moving averages (last 1 eps): recall=0.0000, f1=0.0000, precision=0.0000
# Episode    2 | steps=  2 | reward_sum=4.00 | recall=0.0000 | f1=0.0000 | precision=0.0000
#   >>> Moving averages (last 2 eps): recall=0.0000, f1=0.0000, precision=0.0000
# Episode    3 | steps=  3 | reward_sum=3.00 | recall=0.0000 | f1=0.0000 | precision=0.0000
#   >>> Moving averages (last 3 eps): recall=0.0000, f1=0.0000, precision=0.0000
# Episode    4 | steps=  5 | reward_sum=4.00 | recall=0.0000 | f1=0.0000 | precision=0.0000
#   >>> Moving averages (last 4 eps): recall=0.0000, f1=0.0000, precision=0.0000
# Episode    5 | steps=  2 | reward_sum=4.00 | recall=0.0000 | f1=0.0000 | precision=0.0000
#   >>> Moving averages (last 5 eps): recall=0.0000, f1=0.0000, precision=0.0000
# Episode    6 | steps=  3 | reward_sum=3.00 | recall=0.0000 | f1=0.0000 | precision=0.0000
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %%
import importlib, fraud_env_with_dqn_metrics
importlib.reload(fraud_env_with_dqn_metrics)
from fraud_env_with_dqn_metrics import train_dqn_with_metrics

# %%
policy, target, memory = train_dqn_with_metrics(
    csv_path="dataset/creditcard.csv",
    n_episodes=40,
    max_steps_per_episode=1000,
    batch_size=128,
    moving_avg_window=10,
    device="cpu",
    log_loss=True,   # opcional
)
# Out:
# Episode    1 | steps=1000 | reward_sum=622.00 | recall=0.0000 | f1=0.0000 | precision=0.0000 loss=0.0281
#   >>> Moving averages (last 1 eps): recall=0.0000, f1=0.0000, precision=0.0000
# Episode    2 | steps=1000 | reward_sum=907.00 | recall=0.0000 | f1=0.0000 | precision=0.0000 loss=0.0039
#   >>> Moving averages (last 2 eps): recall=0.0000, f1=0.0000, precision=0.0000
# Episode    3 | steps=1000 | reward_sum=908.00 | recall=0.3333 | f1=0.0625 | precision=0.0345 loss=0.0043
#   >>> Moving averages (last 3 eps): recall=0.1111, f1=0.0208, precision=0.0115
# Episode    4 | steps=1000 | reward_sum=931.00 | recall=0.0000 | f1=0.0000 | precision=0.0000 loss=0.0049
#   >>> Moving averages (last 4 eps): recall=0.0833, f1=0.0156, precision=0.0086
# Episode    5 | steps=1000 | reward_sum=934.00 | recall=0.0000 | f1=0.0000 | precision=0.0000 loss=0.0043
#   >>> Moving averages (last 5 eps): recall=0.0667, f1=0.0125, precision=0.0069
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %%
import importlib, fraud_env_with_dqn_metrics
importlib.reload(fraud_env_with_dqn_metrics)
from fraud_env_with_dqn_metrics import train_dqn_with_metrics

# %%
policy, target, memory = train_dqn_with_metrics(
    csv_path="dataset/creditcard.csv",
    n_episodes=40,
    max_steps_per_episode=1000,
    batch_size=128,
    moving_avg_window=10,
    device="cpu",
    log_loss=True,
    save_plots=True
)
# Out:
# Episode    1 | steps=1000 | reward_sum=345.00 | recall=0.6667 | f1=0.0237 | precision=0.0120 loss=0.1045
#   >>> Moving averages (last 1 eps): recall=0.6667, f1=0.0237, precision=0.0120
# Episode    2 | steps=1000 | reward_sum=911.00 | recall=1.0000 | f1=0.0769 | precision=0.0400 loss=0.0037
#   >>> Moving averages (last 2 eps): recall=0.8333, f1=0.0503, precision=0.0260
# Episode    3 | steps=1000 | reward_sum=891.00 | recall=0.0000 | f1=0.0000 | precision=0.0000 loss=0.0063
#   >>> Moving averages (last 3 eps): recall=0.5556, f1=0.0335, precision=0.0173
# Episode    4 | steps=1000 | reward_sum=928.00 | recall=0.0000 | f1=0.0000 | precision=0.0000 loss=0.0057
#   >>> Moving averages (last 4 eps): recall=0.4167, f1=0.0251, precision=0.0130
# Episode    5 | steps=1000 | reward_sum=917.00 | recall=1.0000 | f1=0.1875 | precision=0.1034 loss=0.0056
#   >>> Moving averages (last 5 eps): recall=0.5333, f1=0.0576, precision=0.0311
# ...

# %%
conda info --envs
# Out:
# # conda environments:
# #
# base                   C:\Users\anton\anaconda3
# LSTM_tf2               C:\Users\anton\anaconda3\envs\LSTM_tf2
# Pennylane_torch_v1     C:\Users\anton\anaconda3\envs\Pennylane_torch_v1
# Pratical_RL_2          C:\Users\anton\anaconda3\envs\Pratical_RL_2
# Pratical_RL_4          C:\Users\anton\anaconda3\envs\Pratical_RL_4
# gymfraud_py311         C:\Users\anton\anaconda3\envs\gymfraud_py311
# gymfraud_py311_smote_v4 * C:\Users\anton\anaconda3\envs\gymfraud_py311_smote_v4
# gymfraud_py311_v2      C:\Users\anton\anaconda3\envs\gymfraud_py311_v2
# nlp_course             C:\Users\anton\anaconda3\envs\nlp_course
# qiskit_3               C:\Users\anton\anaconda3\envs\qiskit_3
# snn_env_2              C:\Users\anton\anaconda3\envs\snn_env_2
# tf_kerasRL_Gym_v1py310   C:\Users\anton\anaconda3\envs\tf_kerasRL_Gym_v1py310
#
#
# Note: you may need to restart the kernel to use updated packages.
